# %% [markdown]
# <a href="https://colab.research.google.com/github/DannyCollinson/EMIT-ECOSTRESS/blob/trunk/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

from tifffile import tifffile
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import torch

# %%
os.chdir('/content/drive/Shareddrives/emit-ecostress')
os.getcwd()
# Out:
# '/content/drive/Shareddrives/emit-ecostress'

# %%
# !git clone https://github.com/DannyCollinson/EMIT-ECOSTRESS.git
# Out:
# fatal: destination path 'EMIT-ECOSTRESS' already exists and is not an empty directory.

# %%
# !git clone https://github.com/DannyCollinson/VITALS.git
# Out:
# fatal: destination path 'VITALS' already exists and is not an empty directory.

# %%
torch.cuda.is_available()
# Out:
# False

# %%
im_day = tifffile.imread('/content/drive/Shareddrives/emit-ecostress/ECOSTRESS_LA_daytime_summer_LST_2018_2021.tif')
im_night = tifffile.imread('/content/drive/Shareddrives/emit-ecostress/ECOSTRESS_LA_nighttime_summer_LST_2018_2021.tif')

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(6, 2.75))
axs[0].imshow(im_day)
axs[0].title.set_text('Day')
axs[1].imshow(im_night)
axs[1].title.set_text('Night')
normalizer = Normalize(min(np.nanmin(im_day), np.nanmin(im_night)), max(np.nanmax(im_day), np.nanmax(im_night)))
plt.imshow(im_day, norm=normalizer)
plt.imshow(im_night, norm=normalizer)
fig.colorbar(ScalarMappable(normalizer), ax=axs, shrink=0.5, fraction=0.5)
fig.suptitle('ECOSTRESS LST for LA summer 2018-2021')
plt.show()
