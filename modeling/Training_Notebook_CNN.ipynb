# %%
import os
import sys
import importlib
import pickle

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

# %%
project_path = 'C:\\Users\\danny\\Documents_Local\\Caltech_2023-2024\\CS101'

def join_path(relative_path: str) -> str:
    return os.path.join(project_path, relative_path)

def pickle_load(relative_path: str):  # -> pickled_file_contents
    return pickle.load(open(join_path(relative_path), 'rb'))

def pickle_save(obj: object, relative_path: str) -> None:
    pickle.dump(obj, open(join_path(relative_path), 'wb'))

# %%
sys.path.append(join_path('EMIT-ECOSTRESS\\modules'))
import datasets.Datasets
import models.Feedforward
import models.Attention
import models.DannyCNN
import utils.train

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
device
# Out:
# 'cuda'

# %%
# For CNN

# Make datasets and dataloaders

y_size = 64
x_size = 64

# setup

importlib.reload(datasets.Datasets)

omit_components = 244 - 32

batch_size = 256

base_data_path = 'Data\\CNN_Data\\Splits'


# load data

emit_train = pickle_load(
    os.path.join(base_data_path, 'reflectance_cnn_train_pca244.pkl')
)
emit_val = pickle_load(
    os.path.join(base_data_path, 'reflectance_cnn_val_pca244.pkl')
)

elev_train = pickle_load(
    os.path.join(base_data_path, 'elevation_cnn_train.pkl')
)
elev_val = pickle_load(os.path.join(base_data_path, 'elevation_cnn_val.pkl'))

eco_train = pickle_load(os.path.join(base_data_path, 'temp_cnn_train.pkl'))
eco_val = pickle_load(os.path.join(base_data_path, 'temp_cnn_val.pkl'))


# create datasets and dataloaders

train_dataset = datasets.Datasets.CNNDataset(
    emit_data=emit_train,
    omit_components=omit_components,
    ecostress_data=eco_train,
    ecostress_center=None,
    ecostress_scale=None,
    additional_data=(elev_train,),
    y_size=y_size,
    x_size=x_size,
)

val_dataset = datasets.Datasets.CNNDataset(
    emit_data=emit_val,
    omit_components=omit_components,
    ecostress_data=eco_val,
    ecostress_center=None,
    ecostress_scale=None,
    additional_data=(elev_val,),
    y_size=y_size,
    x_size=x_size,
)

if batch_size is not None:
    train_loader = DataLoader(
        dataset=train_dataset, batch_size=batch_size, drop_last=True
    )
    val_loader = DataLoader(
        dataset=val_dataset, batch_size=batch_size, drop_last=True
    )
else:
    train_loader = DataLoader(
        dataset=train_dataset, batch_size=batch_size
    )
    val_loader = DataLoader(
        dataset=val_dataset, batch_size=batch_size
    )

# %%
# For CNN

# Make model, optimizer, and loss function
importlib.reload(models.DannyCNN)

model = models.DannyCNN.UNet(
    y_size=y_size,
    x_size=x_size,
    input_dim=train_dataset.input_dim,
    dropout_rate=0.15,
)

if device == 'cuda':
    model = model.cuda()

optimizer = optim.Adam(
    params=model.parameters(), lr=0.0001, weight_decay=0, fused=True
)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer=optimizer, factor=0.5, patience=2
)
# scheduler = None

loss_fn = nn.MSELoss(reduction='mean')

model
# Out:
# UNet(
#   (down1): Conv2d(33, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (up5): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxunpool5): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (up4): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxunpool4): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (up3): ConvTranspose2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxunpool3): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (up2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (maxunpool2): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (up1): ConvTranspose2d(32, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (linear_out1): Linear(in_features=16384, out_features=4096, bias=True)
#   (linear_out2): Linear(in_features=4096, out_features=4096, bias=True)
# )

# %%
importlib.reload(utils.train)

n_epochs = 200

train_loss, val_loss = utils.train.train(
    model,
    optimizer,
    scheduler,
    loss_fn,
    train_loader,
    val_loader,
    n_epochs=n_epochs,
    loss_interval=1,
    # preexisting_losses=[train_loss, val_loss],
    device=device,
)
# Out:
# Epoch 000:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 0.0001	Time: 0.0
# Epoch 001:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 0.0001	Time: 0.0
# Epoch 002:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 0.0001	Time: 0.0
# Epoch 003:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 0.0001	Time: 0.0
# Epoch 004:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 0.0001	Time: 0.0
# Epoch 005:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR:  5e-05	Time: 0.0
# Epoch 006:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR:  5e-05	Time: 0.0
# Epoch 007:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR:  5e-05	Time: 0.0
# Epoch 008:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.5e-05	Time: 0.0
# Epoch 009:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.5e-05	Time: 0.0
# Epoch 010:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.5e-05	Time: 0.0
# Epoch 011:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.25e-05	Time: 0.0
# Epoch 012:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.25e-05	Time: 0.0
# Epoch 013:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.25e-05	Time: 0.0
# Epoch 014:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 6.25e-06	Time: 0.0
# Epoch 015:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 6.25e-06	Time: 0.0
# Epoch 016:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 6.25e-06	Time: 0.0
# Epoch 017:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.125e-06	Time: 0.0
# Epoch 018:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.125e-06	Time: 0.0
# Epoch 019:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.125e-06	Time: 0.0
# Epoch 020:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.5625e-06	Time: 0.0
# Epoch 021:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.5625e-06	Time: 0.0
# Epoch 022:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.5625e-06	Time: 0.0
# Epoch 023:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 7.8125e-07	Time: 0.0
# Epoch 024:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 7.8125e-07	Time: 0.0
# Epoch 025:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 7.8125e-07	Time: 0.0
# Epoch 026:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.9063e-07	Time: 0.0
# Epoch 027:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.9063e-07	Time: 0.0
# Epoch 028:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 3.9063e-07	Time: 0.0
# Epoch 029:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.9531e-07	Time: 0.0
# Epoch 030:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.9531e-07	Time: 0.0
# Epoch 031:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.9531e-07	Time: 0.0
# Epoch 032:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 9.7656e-08	Time: 0.0
# Epoch 033:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 9.7656e-08	Time: 0.0
# Epoch 034:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 9.7656e-08	Time: 0.0
# Epoch 035:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 4.8828e-08	Time: 0.01
# Epoch 036:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 4.8828e-08	Time: 0.0
# Epoch 037:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 4.8828e-08	Time: 0.0
# Epoch 038:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.4414e-08	Time: 0.0
# Epoch 039:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.4414e-08	Time: 0.0
# Epoch 040:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 2.4414e-08	Time: 0.0
# Epoch 041:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 042:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 043:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 044:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 045:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 046:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 047:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 048:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 049:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 050:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 051:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 052:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 053:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 054:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 055:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 056:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00312
# Epoch 057:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 058:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 059:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 060:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 061:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 062:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 063:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00101
# Epoch 064:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 065:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 066:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 067:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 068:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 069:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.000998
# Epoch 070:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 071:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 072:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 073:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 074:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 075:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 076:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 077:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.000999
# Epoch 078:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 079:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 080:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 081:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 082:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 083:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 084:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 085:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 086:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 087:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 088:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 089:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 090:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 091:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 092:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 093:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 094:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 095:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 096:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 097:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 098:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 099:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 100:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 101:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 102:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00366
# Epoch 103:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 104:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 105:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 106:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 107:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 108:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.000765
# Epoch 109:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 110:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 111:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 112:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.000672
# Epoch 113:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 114:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 115:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 116:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 117:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 118:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 119:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 120:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 121:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 122:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 123:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 124:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 125:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 126:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 127:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 128:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 129:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 130:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 131:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 132:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 133:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 134:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 135:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 136:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 137:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 138:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 139:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 140:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 141:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 142:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 143:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 144:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 145:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 146:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 147:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 148:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 149:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 150:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 151:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 152:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 153:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 154:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 155:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 156:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 157:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 158:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 159:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 160:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 161:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 162:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 163:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 164:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 165:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 166:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 167:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 168:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 169:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 170:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 171:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 172:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 173:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 174:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 175:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 176:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00903
# Epoch 177:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 178:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 179:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 180:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 181:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.000746
# Epoch 182:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 183:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 184:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 185:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 186:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 187:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00101
# Epoch 188:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 189:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 190:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 191:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 192:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 193:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 194:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 195:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 196:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.00111
# Epoch 197:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 198:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 199:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0
# Epoch 200:     Train (loss, std, K):     0.0,     0.0,     0.0   	 Val (loss, std, K):     0.0,     0.0,     0.0   	LR: 1.2207e-08	Time: 0.0

# %%
fig, ax = plt.subplots()
fig.suptitle('5-Layer U-Net')
ax.set_title('Input = 42 whitened PCA components + elevation')
ax.semilogy(
    np.arange(len(train_loss)),
    train_loss,
    label=(
        'train, '
        # f'min_loss={min(train_loss):.4}, '
        f'min std={min(train_loss)**(1/2):.4}, '
        f'min K={train_dataset.ecostress_scale * min(train_loss)**(1/2):.4}'
    ),
)
ax.semilogy(
    np.arange(len(val_loss)),
    val_loss,
    label=(
        'val, '
        # f'min_loss={min(val_loss):.4}, '
        f'min std={min(val_loss)**(1/2):.4}, '
        f'min K={val_dataset.ecostress_scale * min(val_loss)**(1/2):.4}'
    ),
)
ax.set_xlabel('Epoch')
ax.set_ylabel('Average MSE Loss')
ax.legend()
plt.show(fig)
